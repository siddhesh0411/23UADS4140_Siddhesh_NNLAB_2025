# %%
import tensorflow.compat.v1 as tf
import tensorflow_datasets as tfds
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import time
from sklearn.metrics import confusion_matrix
from openpyxl import Workbook
tf.disable_v2_behavior()

mnist = tfds.load('mnist', split=['train', 'test'], as_supervised=True)
train_data, test_data = mnist

def preprocess(images, labels):
    images = tf.cast(images, tf.float32) / 255.0  # Normalize
    images = tf.reshape(images, [784])  # Flatten
    labels = tf.one_hot(labels, depth=10)  # One-hot encode
    return images, labels

batch_size_list = [1,10, 100]
epochs_list = [10, 50,100]

def train_and_evaluate(batch_size, epochs):
    print(f"\nTraining with batch_size={batch_size}, epochs={epochs}")

    train_dataset = train_data.map(preprocess).batch(batch_size)
    test_dataset = test_data.map(preprocess).batch(batch_size)

    X = tf.placeholder(tf.float32, [None, 784])
    Y = tf.placeholder(tf.float32, [None, 10])

    weights = {
        'h1': tf.Variable(tf.random_normal([784, 128])),
        'h2': tf.Variable(tf.random_normal([128, 64])),
        'out': tf.Variable(tf.random_normal([64, 10]))
    }
    biases = {
        'b1': tf.Variable(tf.random_normal([128])),
        'b2': tf.Variable(tf.random_normal([64])),
        'out': tf.Variable(tf.random_normal([10]))
    }

    def neural_network(x):
        layer1 = tf.nn.relu(tf.add(tf.matmul(x, weights['h1']), biases['b1']))
        layer2 = tf.nn.relu(tf.add(tf.matmul(layer1, weights['h2']), biases['b2']))
        return tf.add(tf.matmul(layer2, weights['out']), biases['out'])

    logits = neural_network(X)
    loss = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits_v2(logits=logits, labels=Y))
    optimizer = tf.train.AdamOptimizer(learning_rate=0.01).minimize(loss)

    predictions = tf.nn.softmax(logits)
    correct_pred = tf.equal(tf.argmax(predictions, 1), tf.argmax(Y, 1))
    accuracy = tf.reduce_mean(tf.cast(correct_pred, tf.float32))

    loss_curve, acc_curve, val_acc_curve = [], [], []
    start_time = time.time()

    with tf.Session() as sess:
        sess.run(tf.global_variables_initializer())

        for epoch in range(epochs):
            avg_loss = 0
            total_batches = 0
            iterator = tf.compat.v1.data.make_one_shot_iterator(train_dataset)
            next_batch = iterator.get_next()

            while True:
                try:
                    batch_x, batch_y = sess.run(next_batch)
                    _, c = sess.run([optimizer, loss], feed_dict={X: batch_x, Y: batch_y})
                    avg_loss += c
                    total_batches += 1
                except tf.errors.OutOfRangeError:
                    break  

            avg_loss /= total_batches
            train_acc = sess.run(accuracy, feed_dict={X: batch_x, Y: batch_y})
            val_acc = sess.run(accuracy, feed_dict={X: batch_x, Y: batch_y})

            loss_curve.append(avg_loss)
            acc_curve.append(train_acc)
            val_acc_curve.append(val_acc)

            print(f"Epoch {epoch+1}, Loss: {avg_loss:.4f}, Train Acc: {train_acc:.4f}, Val Acc: {val_acc:.4f}")

        end_time = time.time()
        execution_time = end_time - start_time

        test_acc = []
        y_true, y_pred = [], []
        iterator = tf.compat.v1.data.make_one_shot_iterator(test_dataset)
        next_batch = iterator.get_next()

        while True:
            try:
                batch_x, batch_y = sess.run(next_batch)
                acc, preds = sess.run([accuracy, predictions], feed_dict={X: batch_x, Y: batch_y})
                test_acc.append(acc)
                y_pred.extend(np.argmax(preds, axis=1))
                y_true.extend(np.argmax(batch_y, axis=1))
            except tf.errors.OutOfRangeError:
                break

        final_test_acc = np.mean(test_acc)
        print(f"Test Accuracy: {final_test_acc:.4f}")

        conf_matrix = confusion_matrix(y_true, y_pred)
        plt.figure(figsize=(8, 6))
        sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues', xticklabels=range(10), yticklabels=range(10))
        plt.xlabel("Predicted")
        plt.ylabel("Actual")
        plt.title(f"Confusion Matrix (Batch={batch_size}, Epochs={epochs})")
        cm_filename = f"confusion_matrix_batch{batch_size}_epochs{epochs}.png"
        plt.savefig(cm_filename)
        plt.close()

        plt.figure(figsize=(12, 4))

        plt.subplot(1, 2, 1)
        plt.plot(loss_curve, label='Train Loss')
        plt.xlabel("Epochs")
        plt.ylabel("Loss")
        plt.legend()
        plt.title("Loss Curve")

        plt.subplot(1, 2, 2)
        plt.plot(acc_curve, label='Train Accuracy')
        plt.plot(val_acc_curve, label='Val Accuracy')
        plt.xlabel("Epochs")
        plt.ylabel("Accuracy")
        plt.legend()
        plt.title("Accuracy Curve")

        curve_filename = f"curves_batch{batch_size}_epochs{epochs}.png"
        plt.savefig(curve_filename)
        plt.close()

    return batch_size, epochs, execution_time, final_test_acc, cm_filename, curve_filename

results = []
for batch_size in batch_size_list:
    for epochs in epochs_list:
        res = train_and_evaluate(batch_size, epochs)
        results.append(res)

df = pd.DataFrame(results, columns=['Batch Size', 'Epochs', 'Execution Time (s)', 'Test Accuracy', 'Confusion Matrix Image', 'Loss/Accuracy Curves'])
df.to_excel("training_results.xlsx", index=False)

print("\n All Results Saved in training_results.xlsx")
# Out:
# WARNING:tensorflow:From C:\Users\siddh\AppData\Local\Temp\ipykernel_28008\1538282329.py:10: The name tf.disable_v2_behavior is deprecated. Please use tf.compat.v1.disable_v2_behavior instead.
#
# WARNING:tensorflow:From c:\Users\siddh\AppData\Local\Programs\Python\Python311\Lib\site-packages\tensorflow\python\compat\v2_compat.py:98: disable_resource_variables (from tensorflow.python.ops.resource_variables_toggle) is deprecated and will be removed in a future version.
# Instructions for updating:
# non-resource variables are not supported in the long term
#
# Training with batch_size=1, epochs=10
# WARNING:tensorflow:From C:\Users\siddh\AppData\Local\Temp\ipykernel_28008\1538282329.py:51: The name tf.train.AdamOptimizer is deprecated. Please use tf.compat.v1.train.AdamOptimizer instead.
# WARNING:tensorflow:From C:\Users\siddh\AppData\Local\Temp\ipykernel_28008\1538282329.py:51: The name tf.train.AdamOptimizer is deprecated. Please use tf.compat.v1.train.AdamOptimizer instead.
# WARNING:tensorflow:From C:\Users\siddh\AppData\Local\Temp\ipykernel_28008\1538282329.py:66: The name tf.data.make_one_shot_iterator is deprecated. Please use tf.compat.v1.data.make_one_shot_iterator instead.
# WARNING:tensorflow:From C:\Users\siddh\AppData\Local\Temp\ipykernel_28008\1538282329.py:66: The name tf.data.make_one_shot_iterator is deprecated. Please use tf.compat.v1.data.make_one_shot_iterator instead.
# Epoch 1, Loss: 3.1306, Train Acc: 0.0000, Val Acc: 0.0000
# Epoch 2, Loss: 2.3087, Train Acc: 0.0000, Val Acc: 0.0000
# Epoch 3, Loss: 2.3087, Train Acc: 0.0000, Val Acc: 0.0000
# Epoch 4, Loss: 2.3087, Train Acc: 0.0000, Val Acc: 0.0000
# Epoch 5, Loss: 2.3087, Train Acc: 0.0000, Val Acc: 0.0000
# Epoch 6, Loss: 2.3087, Train Acc: 0.0000, Val Acc: 0.0000
# Epoch 7, Loss: 2.3087, Train Acc: 0.0000, Val Acc: 0.0000
# Epoch 8, Loss: 2.3087, Train Acc: 0.0000, Val Acc: 0.0000
# Epoch 9, Loss: 2.3087, Train Acc: 0.0000, Val Acc: 0.0000
# Epoch 10, Loss: 2.3087, Train Acc: 0.0000, Val Acc: 0.0000
# Test Accuracy: 0.1135
#
# Training with batch_size=1, epochs=50
# Epoch 1, Loss: 3.8624, Train Acc: 0.0000, Val Acc: 0.0000
# Epoch 2, Loss: 2.3090, Train Acc: 0.0000, Val Acc: 0.0000
# Epoch 3, Loss: 2.3087, Train Acc: 0.0000, Val Acc: 0.0000
# Epoch 4, Loss: 2.3087, Train Acc: 0.0000, Val Acc: 0.0000
# Epoch 5, Loss: 2.3087, Train Acc: 0.0000, Val Acc: 0.0000
# Epoch 6, Loss: 2.3087, Train Acc: 0.0000, Val Acc: 0.0000
# Epoch 7, Loss: 2.3087, Train Acc: 0.0000, Val Acc: 0.0000
# Epoch 8, Loss: 2.3087, Train Acc: 0.0000, Val Acc: 0.0000
# Epoch 9, Loss: 2.3087, Train Acc: 0.0000, Val Acc: 0.0000
# Epoch 10, Loss: 2.3087, Train Acc: 0.0000, Val Acc: 0.0000
# Epoch 11, Loss: 2.3087, Train Acc: 0.0000, Val Acc: 0.0000
# Epoch 12, Loss: 2.3087, Train Acc: 0.0000, Val Acc: 0.0000
# Epoch 13, Loss: 2.3087, Train Acc: 0.0000, Val Acc: 0.0000
# Epoch 14, Loss: 2.3087, Train Acc: 0.0000, Val Acc: 0.0000
# Epoch 15, Loss: 2.3087, Train Acc: 0.0000, Val Acc: 0.0000
# Epoch 16, Loss: 2.3087, Train Acc: 0.0000, Val Acc: 0.0000
# Epoch 17, Loss: 2.3087, Train Acc: 0.0000, Val Acc: 0.0000
# Epoch 18, Loss: 2.3087, Train Acc: 0.0000, Val Acc: 0.0000
# Epoch 19, Loss: 2.3087, Train Acc: 0.0000, Val Acc: 0.0000
# Epoch 20, Loss: 2.3087, Train Acc: 0.0000, Val Acc: 0.0000
# Epoch 21, Loss: 2.3087, Train Acc: 0.0000, Val Acc: 0.0000
# Epoch 22, Loss: 2.3087, Train Acc: 0.0000, Val Acc: 0.0000
# Epoch 23, Loss: 2.3087, Train Acc: 0.0000, Val Acc: 0.0000
# Epoch 24, Loss: 2.3087, Train Acc: 0.0000, Val Acc: 0.0000
# Epoch 25, Loss: 2.3087, Train Acc: 0.0000, Val Acc: 0.0000
# Epoch 26, Loss: 2.3087, Train Acc: 0.0000, Val Acc: 0.0000
# Epoch 27, Loss: 2.3087, Train Acc: 0.0000, Val Acc: 0.0000
# Epoch 28, Loss: 2.3087, Train Acc: 0.0000, Val Acc: 0.0000
# Epoch 29, Loss: 2.3087, Train Acc: 0.0000, Val Acc: 0.0000
# Epoch 30, Loss: 2.3087, Train Acc: 0.0000, Val Acc: 0.0000
# Epoch 31, Loss: 2.3087, Train Acc: 0.0000, Val Acc: 0.0000
# Epoch 32, Loss: 2.3087, Train Acc: 0.0000, Val Acc: 0.0000
# Epoch 33, Loss: 2.3087, Train Acc: 0.0000, Val Acc: 0.0000
# Epoch 34, Loss: 2.3087, Train Acc: 0.0000, Val Acc: 0.0000
# Epoch 35, Loss: 2.3087, Train Acc: 0.0000, Val Acc: 0.0000
# Epoch 36, Loss: 2.3087, Train Acc: 0.0000, Val Acc: 0.0000
# Epoch 37, Loss: 2.3087, Train Acc: 0.0000, Val Acc: 0.0000
# Epoch 38, Loss: 2.3087, Train Acc: 0.0000, Val Acc: 0.0000
# Epoch 39, Loss: 2.3087, Train Acc: 0.0000, Val Acc: 0.0000
# Epoch 40, Loss: 2.3087, Train Acc: 0.0000, Val Acc: 0.0000
# Epoch 41, Loss: 2.3087, Train Acc: 0.0000, Val Acc: 0.0000
# Epoch 42, Loss: 2.3087, Train Acc: 0.0000, Val Acc: 0.0000
# Epoch 43, Loss: 2.3087, Train Acc: 0.0000, Val Acc: 0.0000
# Epoch 44, Loss: 2.3087, Train Acc: 0.0000, Val Acc: 0.0000
# Epoch 45, Loss: 2.3087, Train Acc: 0.0000, Val Acc: 0.0000
# Epoch 46, Loss: 2.3087, Train Acc: 0.0000, Val Acc: 0.0000
# Epoch 47, Loss: 2.3087, Train Acc: 0.0000, Val Acc: 0.0000
# Epoch 48, Loss: 2.3087, Train Acc: 0.0000, Val Acc: 0.0000
# Epoch 49, Loss: 2.3087, Train Acc: 0.0000, Val Acc: 0.0000
# Epoch 50, Loss: 2.3087, Train Acc: 0.0000, Val Acc: 0.0000
# Test Accuracy: 0.1135
#
# Training with batch_size=1, epochs=100
# Epoch 1, Loss: 3.2476, Train Acc: 0.0000, Val Acc: 0.0000
# Epoch 2, Loss: 2.3258, Train Acc: 0.0000, Val Acc: 0.0000
# Epoch 3, Loss: 2.2818, Train Acc: 0.0000, Val Acc: 0.0000
# Epoch 4, Loss: 2.3009, Train Acc: 0.0000, Val Acc: 0.0000
# Epoch 5, Loss: 2.2866, Train Acc: 0.0000, Val Acc: 0.0000
# Epoch 6, Loss: 2.2760, Train Acc: 0.0000, Val Acc: 0.0000
# Epoch 7, Loss: 2.3370, Train Acc: 0.0000, Val Acc: 0.0000
# Epoch 8, Loss: 2.2637, Train Acc: 0.0000, Val Acc: 0.0000
# Epoch 9, Loss: 2.2623, Train Acc: 0.0000, Val Acc: 0.0000
# Epoch 10, Loss: 2.2872, Train Acc: 0.0000, Val Acc: 0.0000
# Epoch 11, Loss: 2.2385, Train Acc: 0.0000, Val Acc: 0.0000
# Epoch 12, Loss: 2.2607, Train Acc: 0.0000, Val Acc: 0.0000
# Epoch 13, Loss: 2.2245, Train Acc: 0.0000, Val Acc: 0.0000
# Epoch 14, Loss: 2.2456, Train Acc: 0.0000, Val Acc: 0.0000
# Epoch 15, Loss: 2.3195, Train Acc: 0.0000, Val Acc: 0.0000
# Epoch 16, Loss: 2.2583, Train Acc: 0.0000, Val Acc: 0.0000
# Epoch 17, Loss: 2.2747, Train Acc: 0.0000, Val Acc: 0.0000
# Epoch 18, Loss: 2.1579, Train Acc: 0.0000, Val Acc: 0.0000
# Epoch 19, Loss: 2.3076, Train Acc: 0.0000, Val Acc: 0.0000
# Epoch 20, Loss: 2.1901, Train Acc: 0.0000, Val Acc: 0.0000
# Epoch 21, Loss: 2.1740, Train Acc: 0.0000, Val Acc: 0.0000
# Epoch 22, Loss: 2.2735, Train Acc: 0.0000, Val Acc: 0.0000
# Epoch 23, Loss: 2.1390, Train Acc: 0.0000, Val Acc: 0.0000
# Epoch 24, Loss: 2.3023, Train Acc: 0.0000, Val Acc: 0.0000
# Epoch 25, Loss: 2.1397, Train Acc: 0.0000, Val Acc: 0.0000
# Epoch 26, Loss: 2.2866, Train Acc: 0.0000, Val Acc: 0.0000
# Epoch 27, Loss: 2.2925, Train Acc: 0.0000, Val Acc: 0.0000
# Epoch 28, Loss: 2.2353, Train Acc: 0.0000, Val Acc: 0.0000
# Epoch 29, Loss: 2.1593, Train Acc: 0.0000, Val Acc: 0.0000
# Epoch 30, Loss: 2.2847, Train Acc: 0.0000, Val Acc: 0.0000
# Epoch 31, Loss: 2.2591, Train Acc: 0.0000, Val Acc: 0.0000
# Epoch 32, Loss: 2.1394, Train Acc: 0.0000, Val Acc: 0.0000
# Epoch 33, Loss: 2.2226, Train Acc: 0.0000, Val Acc: 0.0000
# Epoch 34, Loss: 2.2412, Train Acc: 0.0000, Val Acc: 0.0000
# Epoch 35, Loss: 2.2294, Train Acc: 0.0000, Val Acc: 0.0000
# Epoch 36, Loss: 2.2222, Train Acc: 0.0000, Val Acc: 0.0000
# Epoch 37, Loss: 2.5416, Train Acc: 0.0000, Val Acc: 0.0000
# Epoch 38, Loss: 2.1231, Train Acc: 0.0000, Val Acc: 0.0000
# Epoch 39, Loss: 2.2903, Train Acc: 0.0000, Val Acc: 0.0000
# Epoch 40, Loss: 2.1903, Train Acc: 0.0000, Val Acc: 0.0000
# Epoch 41, Loss: 2.2790, Train Acc: 0.0000, Val Acc: 0.0000
# Epoch 42, Loss: 2.2361, Train Acc: 0.0000, Val Acc: 0.0000
# Epoch 43, Loss: 2.3918, Train Acc: 0.0000, Val Acc: 0.0000
# Epoch 44, Loss: 2.1613, Train Acc: 0.0000, Val Acc: 0.0000
# Epoch 45, Loss: 2.2672, Train Acc: 0.0000, Val Acc: 0.0000
# Epoch 46, Loss: 2.1532, Train Acc: 0.0000, Val Acc: 0.0000
# Epoch 47, Loss: 2.1640, Train Acc: 0.0000, Val Acc: 0.0000
# Epoch 48, Loss: 2.1229, Train Acc: 0.0000, Val Acc: 0.0000
# Epoch 49, Loss: 2.0916, Train Acc: 0.0000, Val Acc: 0.0000
# Epoch 50, Loss: 2.0894, Train Acc: 0.0000, Val Acc: 0.0000
# Epoch 51, Loss: 2.0414, Train Acc: 0.0000, Val Acc: 0.0000
# Epoch 52, Loss: 2.2864, Train Acc: 0.0000, Val Acc: 0.0000
# Epoch 53, Loss: 2.2367, Train Acc: 0.0000, Val Acc: 0.0000
# Epoch 54, Loss: 2.2322, Train Acc: 0.0000, Val Acc: 0.0000
# Epoch 55, Loss: 2.1233, Train Acc: 0.0000, Val Acc: 0.0000
# Epoch 56, Loss: 2.0516, Train Acc: 0.0000, Val Acc: 0.0000
# Epoch 57, Loss: 2.0516, Train Acc: 0.0000, Val Acc: 0.0000
# Epoch 58, Loss: 2.0516, Train Acc: 0.0000, Val Acc: 0.0000
# Epoch 59, Loss: 2.0516, Train Acc: 0.0000, Val Acc: 0.0000
# Epoch 60, Loss: 2.0516, Train Acc: 0.0000, Val Acc: 0.0000
# Epoch 61, Loss: 2.0516, Train Acc: 0.0000, Val Acc: 0.0000
# Epoch 62, Loss: 2.0516, Train Acc: 0.0000, Val Acc: 0.0000
# Epoch 63, Loss: 2.0516, Train Acc: 0.0000, Val Acc: 0.0000
# Epoch 64, Loss: 2.0516, Train Acc: 0.0000, Val Acc: 0.0000
# Epoch 65, Loss: 2.0516, Train Acc: 0.0000, Val Acc: 0.0000
# Epoch 66, Loss: 2.0516, Train Acc: 0.0000, Val Acc: 0.0000
# Epoch 67, Loss: 2.0516, Train Acc: 0.0000, Val Acc: 0.0000
# Epoch 68, Loss: 2.0516, Train Acc: 0.0000, Val Acc: 0.0000
# Epoch 69, Loss: 2.0516, Train Acc: 0.0000, Val Acc: 0.0000
# Epoch 70, Loss: 2.0516, Train Acc: 0.0000, Val Acc: 0.0000
# Epoch 71, Loss: 2.0516, Train Acc: 0.0000, Val Acc: 0.0000
# Epoch 72, Loss: 2.0516, Train Acc: 0.0000, Val Acc: 0.0000
# Epoch 73, Loss: 2.0516, Train Acc: 0.0000, Val Acc: 0.0000
# Epoch 74, Loss: 2.0516, Train Acc: 0.0000, Val Acc: 0.0000
# Epoch 75, Loss: 2.0516, Train Acc: 0.0000, Val Acc: 0.0000
# Epoch 76, Loss: 2.0516, Train Acc: 0.0000, Val Acc: 0.0000
# Epoch 77, Loss: 2.0516, Train Acc: 0.0000, Val Acc: 0.0000
# Epoch 78, Loss: 2.0516, Train Acc: 0.0000, Val Acc: 0.0000
# Epoch 79, Loss: 2.0516, Train Acc: 0.0000, Val Acc: 0.0000
# Epoch 80, Loss: 2.0516, Train Acc: 0.0000, Val Acc: 0.0000
# Epoch 81, Loss: 2.0516, Train Acc: 0.0000, Val Acc: 0.0000
# Epoch 82, Loss: 2.0516, Train Acc: 0.0000, Val Acc: 0.0000
# Epoch 83, Loss: 2.0516, Train Acc: 0.0000, Val Acc: 0.0000
# Epoch 84, Loss: 2.0516, Train Acc: 0.0000, Val Acc: 0.0000
# Epoch 85, Loss: 2.0516, Train Acc: 0.0000, Val Acc: 0.0000
# Epoch 86, Loss: 2.0516, Train Acc: 0.0000, Val Acc: 0.0000
# Epoch 87, Loss: 2.0516, Train Acc: 0.0000, Val Acc: 0.0000
# Epoch 88, Loss: 2.0516, Train Acc: 0.0000, Val Acc: 0.0000
# Epoch 89, Loss: 2.0516, Train Acc: 0.0000, Val Acc: 0.0000
# Epoch 90, Loss: 2.0516, Train Acc: 0.0000, Val Acc: 0.0000
# Epoch 91, Loss: 2.0516, Train Acc: 0.0000, Val Acc: 0.0000
# Epoch 92, Loss: 2.0516, Train Acc: 0.0000, Val Acc: 0.0000
# Epoch 93, Loss: 2.0516, Train Acc: 0.0000, Val Acc: 0.0000
# Epoch 94, Loss: 2.0516, Train Acc: 0.0000, Val Acc: 0.0000
# Epoch 95, Loss: 2.0516, Train Acc: 0.0000, Val Acc: 0.0000
# Epoch 96, Loss: 2.0516, Train Acc: 0.0000, Val Acc: 0.0000
# Epoch 97, Loss: 2.0516, Train Acc: 0.0000, Val Acc: 0.0000
# Epoch 98, Loss: 2.0516, Train Acc: 0.0000, Val Acc: 0.0000
# Epoch 99, Loss: 2.0516, Train Acc: 0.0000, Val Acc: 0.0000
# Epoch 100, Loss: 2.0516, Train Acc: 0.0000, Val Acc: 0.0000
# Test Accuracy: 0.1912
#
# Training with batch_size=10, epochs=10
# Epoch 1, Loss: 4.3915, Train Acc: 0.8000, Val Acc: 0.8000
# Epoch 2, Loss: 0.8548, Train Acc: 0.8000, Val Acc: 0.8000
# Epoch 3, Loss: 0.6494, Train Acc: 1.0000, Val Acc: 1.0000
# Epoch 4, Loss: 0.5905, Train Acc: 0.9000, Val Acc: 0.9000
# Epoch 5, Loss: 0.5291, Train Acc: 0.9000, Val Acc: 0.9000
# Epoch 6, Loss: 0.5079, Train Acc: 1.0000, Val Acc: 1.0000
# Epoch 7, Loss: 0.5091, Train Acc: 1.0000, Val Acc: 1.0000
# Epoch 8, Loss: 0.5075, Train Acc: 0.9000, Val Acc: 0.9000
# Epoch 9, Loss: 0.5266, Train Acc: 0.9000, Val Acc: 0.9000
# Epoch 10, Loss: 0.4969, Train Acc: 1.0000, Val Acc: 1.0000
# Test Accuracy: 0.8532
#
# Training with batch_size=10, epochs=50
# Epoch 1, Loss: 3.7316, Train Acc: 0.7000, Val Acc: 0.7000
# Epoch 2, Loss: 0.7369, Train Acc: 1.0000, Val Acc: 1.0000
# Epoch 3, Loss: 0.5374, Train Acc: 1.0000, Val Acc: 1.0000
# Epoch 4, Loss: 0.4325, Train Acc: 1.0000, Val Acc: 1.0000
# Epoch 5, Loss: 0.3969, Train Acc: 1.0000, Val Acc: 1.0000
# Epoch 6, Loss: 0.3806, Train Acc: 1.0000, Val Acc: 1.0000
# Epoch 7, Loss: 0.3834, Train Acc: 1.0000, Val Acc: 1.0000
# Epoch 8, Loss: 0.3967, Train Acc: 1.0000, Val Acc: 1.0000
# Epoch 9, Loss: 0.4142, Train Acc: 1.0000, Val Acc: 1.0000
# Epoch 10, Loss: 0.3935, Train Acc: 1.0000, Val Acc: 1.0000
# Epoch 11, Loss: 0.3953, Train Acc: 0.9000, Val Acc: 0.9000
# Epoch 12, Loss: 0.4270, Train Acc: 1.0000, Val Acc: 1.0000
# Epoch 13, Loss: 0.3667, Train Acc: 1.0000, Val Acc: 1.0000
# Epoch 14, Loss: 0.3963, Train Acc: 1.0000, Val Acc: 1.0000
# Epoch 15, Loss: 0.4255, Train Acc: 1.0000, Val Acc: 1.0000
# Epoch 16, Loss: 0.4332, Train Acc: 1.0000, Val Acc: 1.0000
# Epoch 17, Loss: 0.4266, Train Acc: 1.0000, Val Acc: 1.0000
# Epoch 18, Loss: 0.4968, Train Acc: 1.0000, Val Acc: 1.0000
# Epoch 19, Loss: 0.4161, Train Acc: 1.0000, Val Acc: 1.0000
# Epoch 20, Loss: 0.5494, Train Acc: 1.0000, Val Acc: 1.0000
# Epoch 21, Loss: 0.4778, Train Acc: 1.0000, Val Acc: 1.0000
# Epoch 22, Loss: 0.4691, Train Acc: 1.0000, Val Acc: 1.0000
# Epoch 23, Loss: 0.4681, Train Acc: 0.9000, Val Acc: 0.9000
# Epoch 24, Loss: 0.4676, Train Acc: 1.0000, Val Acc: 1.0000
# Epoch 25, Loss: 0.4734, Train Acc: 0.9000, Val Acc: 0.9000
# Epoch 26, Loss: 0.5068, Train Acc: 0.9000, Val Acc: 0.9000
# Epoch 27, Loss: 0.4861, Train Acc: 1.0000, Val Acc: 1.0000
# Epoch 28, Loss: 0.5114, Train Acc: 0.9000, Val Acc: 0.9000
# Epoch 29, Loss: 0.4231, Train Acc: 1.0000, Val Acc: 1.0000
# Epoch 30, Loss: 0.5562, Train Acc: 0.9000, Val Acc: 0.9000
# Epoch 31, Loss: 0.4908, Train Acc: 1.0000, Val Acc: 1.0000
# Epoch 32, Loss: 0.5656, Train Acc: 0.8000, Val Acc: 0.8000
# Epoch 33, Loss: 0.5750, Train Acc: 1.0000, Val Acc: 1.0000
# Epoch 34, Loss: 0.6614, Train Acc: 1.0000, Val Acc: 1.0000
# Epoch 35, Loss: 0.6864, Train Acc: 0.9000, Val Acc: 0.9000
# Epoch 36, Loss: 0.5950, Train Acc: 1.0000, Val Acc: 1.0000
# Epoch 37, Loss: 0.7655, Train Acc: 1.0000, Val Acc: 1.0000
# Epoch 38, Loss: 0.6742, Train Acc: 0.9000, Val Acc: 0.9000
# Epoch 39, Loss: 0.6655, Train Acc: 0.9000, Val Acc: 0.9000
# Epoch 40, Loss: 0.7891, Train Acc: 1.0000, Val Acc: 1.0000
# Epoch 41, Loss: 0.7389, Train Acc: 0.9000, Val Acc: 0.9000
# Epoch 42, Loss: 0.7629, Train Acc: 0.9000, Val Acc: 0.9000
# Epoch 43, Loss: 0.7931, Train Acc: 1.0000, Val Acc: 1.0000
# Epoch 44, Loss: 0.8068, Train Acc: 0.7000, Val Acc: 0.7000
# Epoch 45, Loss: 0.7478, Train Acc: 0.9000, Val Acc: 0.9000
# Epoch 46, Loss: 1.0231, Train Acc: 0.9000, Val Acc: 0.9000
# Epoch 47, Loss: 0.8036, Train Acc: 0.7000, Val Acc: 0.7000
# Epoch 48, Loss: 0.8729, Train Acc: 0.9000, Val Acc: 0.9000
# Epoch 49, Loss: 1.1570, Train Acc: 0.8000, Val Acc: 0.8000
# Epoch 50, Loss: 0.8928, Train Acc: 0.9000, Val Acc: 0.9000
# Test Accuracy: 0.6973
#
# Training with batch_size=10, epochs=100
# Epoch 1, Loss: 4.2678, Train Acc: 0.8000, Val Acc: 0.8000
# Epoch 2, Loss: 0.6913, Train Acc: 0.9000, Val Acc: 0.9000
# Epoch 3, Loss: 0.5015, Train Acc: 1.0000, Val Acc: 1.0000
# Epoch 4, Loss: 0.4564, Train Acc: 1.0000, Val Acc: 1.0000
# Epoch 5, Loss: 0.4132, Train Acc: 1.0000, Val Acc: 1.0000
# Epoch 6, Loss: 0.3909, Train Acc: 1.0000, Val Acc: 1.0000
# Epoch 7, Loss: 0.3867, Train Acc: 1.0000, Val Acc: 1.0000
# Epoch 8, Loss: 0.3725, Train Acc: 1.0000, Val Acc: 1.0000
# Epoch 9, Loss: 0.3516, Train Acc: 1.0000, Val Acc: 1.0000
# Epoch 10, Loss: 0.3758, Train Acc: 1.0000, Val Acc: 1.0000
# Epoch 11, Loss: 0.3789, Train Acc: 1.0000, Val Acc: 1.0000
# Epoch 12, Loss: 0.3576, Train Acc: 1.0000, Val Acc: 1.0000
# Epoch 13, Loss: 0.3701, Train Acc: 0.9000, Val Acc: 0.9000
# Epoch 14, Loss: 0.3586, Train Acc: 0.8000, Val Acc: 0.8000
# Epoch 15, Loss: 0.3652, Train Acc: 1.0000, Val Acc: 1.0000
# Epoch 16, Loss: 0.3547, Train Acc: 1.0000, Val Acc: 1.0000
# Epoch 17, Loss: 0.3717, Train Acc: 0.9000, Val Acc: 0.9000
# Epoch 18, Loss: 0.3638, Train Acc: 1.0000, Val Acc: 1.0000
# Epoch 19, Loss: 0.4058, Train Acc: 1.0000, Val Acc: 1.0000
# Epoch 20, Loss: 0.3928, Train Acc: 1.0000, Val Acc: 1.0000
# Epoch 21, Loss: 0.4277, Train Acc: 0.8000, Val Acc: 0.8000
# Epoch 22, Loss: 0.4256, Train Acc: 0.9000, Val Acc: 0.9000
# Epoch 23, Loss: 0.4786, Train Acc: 0.9000, Val Acc: 0.9000
# Epoch 24, Loss: 0.4124, Train Acc: 0.9000, Val Acc: 0.9000
# Epoch 25, Loss: 0.4461, Train Acc: 1.0000, Val Acc: 1.0000
# Epoch 26, Loss: 0.4435, Train Acc: 1.0000, Val Acc: 1.0000
# Epoch 27, Loss: 0.5160, Train Acc: 0.9000, Val Acc: 0.9000
# Epoch 28, Loss: 0.4379, Train Acc: 1.0000, Val Acc: 1.0000
# Epoch 29, Loss: 0.4622, Train Acc: 0.9000, Val Acc: 0.9000
# Epoch 30, Loss: 0.4264, Train Acc: 1.0000, Val Acc: 1.0000
# Epoch 31, Loss: 0.4330, Train Acc: 1.0000, Val Acc: 1.0000
# Epoch 32, Loss: 0.4997, Train Acc: 0.9000, Val Acc: 0.9000
# Epoch 33, Loss: 0.4609, Train Acc: 0.9000, Val Acc: 0.9000
# Epoch 34, Loss: 0.4926, Train Acc: 0.9000, Val Acc: 0.9000
# Epoch 35, Loss: 0.5585, Train Acc: 0.9000, Val Acc: 0.9000
# Epoch 36, Loss: 0.4742, Train Acc: 0.9000, Val Acc: 0.9000
# Epoch 37, Loss: 0.4951, Train Acc: 0.9000, Val Acc: 0.9000
# Epoch 38, Loss: 0.5435, Train Acc: 1.0000, Val Acc: 1.0000
# Epoch 39, Loss: 0.5187, Train Acc: 1.0000, Val Acc: 1.0000
# Epoch 40, Loss: 0.5190, Train Acc: 1.0000, Val Acc: 1.0000
# Epoch 41, Loss: 0.6095, Train Acc: 0.9000, Val Acc: 0.9000
# Epoch 42, Loss: 0.5945, Train Acc: 0.9000, Val Acc: 0.9000
# Epoch 43, Loss: 0.5668, Train Acc: 0.9000, Val Acc: 0.9000
# Epoch 44, Loss: 0.5339, Train Acc: 1.0000, Val Acc: 1.0000
# Epoch 45, Loss: 0.6615, Train Acc: 0.9000, Val Acc: 0.9000
# Epoch 46, Loss: 0.6404, Train Acc: 1.0000, Val Acc: 1.0000
# Epoch 47, Loss: 0.5631, Train Acc: 0.9000, Val Acc: 0.9000
# Epoch 48, Loss: 0.5475, Train Acc: 0.9000, Val Acc: 0.9000
# Epoch 49, Loss: 0.6497, Train Acc: 0.9000, Val Acc: 0.9000
# Epoch 50, Loss: 0.6658, Train Acc: 0.9000, Val Acc: 0.9000
# Epoch 51, Loss: 0.7600, Train Acc: 0.8000, Val Acc: 0.8000
# Epoch 52, Loss: 0.6982, Train Acc: 1.0000, Val Acc: 1.0000
# Epoch 53, Loss: 0.7348, Train Acc: 0.9000, Val Acc: 0.9000
# Epoch 54, Loss: 0.6363, Train Acc: 0.8000, Val Acc: 0.8000
# Epoch 55, Loss: 0.5738, Train Acc: 0.9000, Val Acc: 0.9000
# Epoch 56, Loss: 0.7172, Train Acc: 1.0000, Val Acc: 1.0000
# Epoch 57, Loss: 0.9136, Train Acc: 0.9000, Val Acc: 0.9000
# Epoch 58, Loss: 0.6842, Train Acc: 0.7000, Val Acc: 0.7000
# Epoch 59, Loss: 0.7363, Train Acc: 0.8000, Val Acc: 0.8000
# Epoch 60, Loss: 0.8589, Train Acc: 0.9000, Val Acc: 0.9000
# Epoch 61, Loss: 0.8399, Train Acc: 0.7000, Val Acc: 0.7000
# Epoch 62, Loss: 0.7662, Train Acc: 0.9000, Val Acc: 0.9000
# Epoch 63, Loss: 0.8562, Train Acc: 0.9000, Val Acc: 0.9000
# Epoch 64, Loss: 0.8546, Train Acc: 0.9000, Val Acc: 0.9000
# Epoch 65, Loss: 0.8707, Train Acc: 0.9000, Val Acc: 0.9000
# Epoch 66, Loss: 0.8513, Train Acc: 0.8000, Val Acc: 0.8000
# Epoch 67, Loss: 0.7550, Train Acc: 0.8000, Val Acc: 0.8000
# Epoch 68, Loss: 0.7066, Train Acc: 0.6000, Val Acc: 0.6000
# Epoch 69, Loss: 0.9366, Train Acc: 0.7000, Val Acc: 0.7000
# Epoch 70, Loss: 0.8466, Train Acc: 0.9000, Val Acc: 0.9000
# Epoch 71, Loss: 1.0026, Train Acc: 0.8000, Val Acc: 0.8000
# Epoch 72, Loss: 0.9787, Train Acc: 0.7000, Val Acc: 0.7000
# Epoch 73, Loss: 1.1476, Train Acc: 0.7000, Val Acc: 0.7000
# Epoch 74, Loss: 0.9955, Train Acc: 0.8000, Val Acc: 0.8000
# Epoch 75, Loss: 1.1728, Train Acc: 0.8000, Val Acc: 0.8000
# Epoch 76, Loss: 1.0376, Train Acc: 0.7000, Val Acc: 0.7000
# Epoch 77, Loss: 0.9729, Train Acc: 0.8000, Val Acc: 0.8000
# Epoch 78, Loss: 1.1156, Train Acc: 0.8000, Val Acc: 0.8000
# Epoch 79, Loss: 1.2941, Train Acc: 0.6000, Val Acc: 0.6000
# Epoch 80, Loss: 0.9317, Train Acc: 0.7000, Val Acc: 0.7000
# Epoch 81, Loss: 1.0014, Train Acc: 0.8000, Val Acc: 0.8000
# Epoch 82, Loss: 0.9727, Train Acc: 0.7000, Val Acc: 0.7000
# Epoch 83, Loss: 1.0494, Train Acc: 0.8000, Val Acc: 0.8000
# Epoch 84, Loss: 0.8665, Train Acc: 0.8000, Val Acc: 0.8000
# Epoch 85, Loss: 1.0024, Train Acc: 0.6000, Val Acc: 0.6000
# Epoch 86, Loss: 0.8491, Train Acc: 0.6000, Val Acc: 0.6000
# Epoch 87, Loss: 1.0007, Train Acc: 0.6000, Val Acc: 0.6000
# Epoch 88, Loss: 1.1891, Train Acc: 0.6000, Val Acc: 0.6000
# Epoch 89, Loss: 1.0285, Train Acc: 0.6000, Val Acc: 0.6000
# Epoch 90, Loss: 0.9456, Train Acc: 0.5000, Val Acc: 0.5000
# Epoch 91, Loss: 1.7187, Train Acc: 0.6000, Val Acc: 0.6000
# Epoch 92, Loss: 1.3991, Train Acc: 0.7000, Val Acc: 0.7000
# Epoch 93, Loss: 0.9824, Train Acc: 0.8000, Val Acc: 0.8000
# Epoch 94, Loss: 1.2299, Train Acc: 0.7000, Val Acc: 0.7000
# Epoch 95, Loss: 1.1079, Train Acc: 0.5000, Val Acc: 0.5000
# Epoch 96, Loss: 1.1446, Train Acc: 0.6000, Val Acc: 0.6000
# Epoch 97, Loss: 1.1135, Train Acc: 0.6000, Val Acc: 0.6000
# Epoch 98, Loss: 0.9587, Train Acc: 0.6000, Val Acc: 0.6000
# Epoch 99, Loss: 0.9546, Train Acc: 0.8000, Val Acc: 0.8000
# Epoch 100, Loss: 1.1270, Train Acc: 0.6000, Val Acc: 0.6000
# Test Accuracy: 0.6925
#
# Training with batch_size=100, epochs=10
# Epoch 1, Loss: 12.1398, Train Acc: 0.7900, Val Acc: 0.7900
# Epoch 2, Loss: 0.8761, Train Acc: 0.8700, Val Acc: 0.8700
# Epoch 3, Loss: 0.6012, Train Acc: 0.8900, Val Acc: 0.8900
# Epoch 4, Loss: 0.4635, Train Acc: 0.9400, Val Acc: 0.9400
# Epoch 5, Loss: 0.3839, Train Acc: 0.9400, Val Acc: 0.9400
# Epoch 6, Loss: 0.3317, Train Acc: 0.9300, Val Acc: 0.9300
# Epoch 7, Loss: 0.2910, Train Acc: 0.9900, Val Acc: 0.9900
# Epoch 8, Loss: 0.2531, Train Acc: 0.9700, Val Acc: 0.9700
# Epoch 9, Loss: 0.2336, Train Acc: 0.9600, Val Acc: 0.9600
# Epoch 10, Loss: 0.2098, Train Acc: 0.9900, Val Acc: 0.9900
# Test Accuracy: 0.9376
#
# Training with batch_size=100, epochs=50
# Epoch 1, Loss: 13.6167, Train Acc: 0.9000, Val Acc: 0.9000
# Epoch 2, Loss: 1.1337, Train Acc: 0.8600, Val Acc: 0.8600
# Epoch 3, Loss: 0.5771, Train Acc: 0.9300, Val Acc: 0.9300
# Epoch 4, Loss: 0.4091, Train Acc: 0.9400, Val Acc: 0.9400
# Epoch 5, Loss: 0.3335, Train Acc: 0.9500, Val Acc: 0.9500
# Epoch 6, Loss: 0.2814, Train Acc: 0.9600, Val Acc: 0.9600
# Epoch 7, Loss: 0.2536, Train Acc: 0.9700, Val Acc: 0.9700
# Epoch 8, Loss: 0.2291, Train Acc: 0.9600, Val Acc: 0.9600
# Epoch 9, Loss: 0.2155, Train Acc: 0.9800, Val Acc: 0.9800
# Epoch 10, Loss: 0.1984, Train Acc: 0.9900, Val Acc: 0.9900
# Epoch 11, Loss: 0.1943, Train Acc: 0.9800, Val Acc: 0.9800
# Epoch 12, Loss: 0.1679, Train Acc: 0.9900, Val Acc: 0.9900
# Epoch 13, Loss: 0.1622, Train Acc: 0.9800, Val Acc: 0.9800
# Epoch 14, Loss: 0.1494, Train Acc: 0.9800, Val Acc: 0.9800
# Epoch 15, Loss: 0.1371, Train Acc: 0.9800, Val Acc: 0.9800
# Epoch 16, Loss: 0.1213, Train Acc: 0.9900, Val Acc: 0.9900
# Epoch 17, Loss: 0.1220, Train Acc: 0.9900, Val Acc: 0.9900
# Epoch 18, Loss: 0.1150, Train Acc: 0.9800, Val Acc: 0.9800
# Epoch 19, Loss: 0.1041, Train Acc: 0.9800, Val Acc: 0.9800
# Epoch 20, Loss: 0.1029, Train Acc: 0.9800, Val Acc: 0.9800
# Epoch 21, Loss: 0.0987, Train Acc: 0.9800, Val Acc: 0.9800
# Epoch 22, Loss: 0.0996, Train Acc: 0.9900, Val Acc: 0.9900
# Epoch 23, Loss: 0.0904, Train Acc: 0.9900, Val Acc: 0.9900
# Epoch 24, Loss: 0.0938, Train Acc: 0.9800, Val Acc: 0.9800
# Epoch 25, Loss: 0.0933, Train Acc: 0.9900, Val Acc: 0.9900
# Epoch 26, Loss: 0.0862, Train Acc: 0.9800, Val Acc: 0.9800
# Epoch 27, Loss: 0.0751, Train Acc: 0.9900, Val Acc: 0.9900
# Epoch 28, Loss: 0.0838, Train Acc: 0.9800, Val Acc: 0.9800
# Epoch 29, Loss: 0.0813, Train Acc: 0.9800, Val Acc: 0.9800
# Epoch 30, Loss: 0.0826, Train Acc: 0.9800, Val Acc: 0.9800
# Epoch 31, Loss: 0.0729, Train Acc: 0.9900, Val Acc: 0.9900
# Epoch 32, Loss: 0.0829, Train Acc: 0.9800, Val Acc: 0.9800
# Epoch 33, Loss: 0.0739, Train Acc: 0.9800, Val Acc: 0.9800
# Epoch 34, Loss: 0.0753, Train Acc: 0.9800, Val Acc: 0.9800
# Epoch 35, Loss: 0.0837, Train Acc: 0.9900, Val Acc: 0.9900
# Epoch 36, Loss: 0.0772, Train Acc: 0.9800, Val Acc: 0.9800
# Epoch 37, Loss: 0.0816, Train Acc: 0.9900, Val Acc: 0.9900
# Epoch 38, Loss: 0.0650, Train Acc: 0.9900, Val Acc: 0.9900
# Epoch 39, Loss: 0.0660, Train Acc: 0.9900, Val Acc: 0.9900
# Epoch 40, Loss: 0.0668, Train Acc: 0.9900, Val Acc: 0.9900
# Epoch 41, Loss: 0.0647, Train Acc: 0.9900, Val Acc: 0.9900
# Epoch 42, Loss: 0.0601, Train Acc: 0.9900, Val Acc: 0.9900
# Epoch 43, Loss: 0.0686, Train Acc: 0.9800, Val Acc: 0.9800
# Epoch 44, Loss: 0.0708, Train Acc: 0.9800, Val Acc: 0.9800
# Epoch 45, Loss: 0.0603, Train Acc: 0.9800, Val Acc: 0.9800
# Epoch 46, Loss: 0.0620, Train Acc: 0.9800, Val Acc: 0.9800
# Epoch 47, Loss: 0.0555, Train Acc: 1.0000, Val Acc: 1.0000
# Epoch 48, Loss: 0.0646, Train Acc: 0.9900, Val Acc: 0.9900
# Epoch 49, Loss: 0.0553, Train Acc: 0.9900, Val Acc: 0.9900
# Epoch 50, Loss: 0.0693, Train Acc: 0.9700, Val Acc: 0.9700
# Test Accuracy: 0.9603
#
# Training with batch_size=100, epochs=100
# Epoch 1, Loss: 11.4448, Train Acc: 0.7800, Val Acc: 0.7800
# Epoch 2, Loss: 0.8695, Train Acc: 0.8700, Val Acc: 0.8700
# Epoch 3, Loss: 0.5712, Train Acc: 0.9000, Val Acc: 0.9000
# Epoch 4, Loss: 0.4335, Train Acc: 0.9300, Val Acc: 0.9300
# Epoch 5, Loss: 0.3444, Train Acc: 0.9600, Val Acc: 0.9600
# Epoch 6, Loss: 0.2923, Train Acc: 0.9600, Val Acc: 0.9600
# Epoch 7, Loss: 0.2529, Train Acc: 0.9800, Val Acc: 0.9800
# Epoch 8, Loss: 0.2218, Train Acc: 0.9900, Val Acc: 0.9900
# Epoch 9, Loss: 0.2019, Train Acc: 0.9800, Val Acc: 0.9800
# Epoch 10, Loss: 0.1786, Train Acc: 0.9700, Val Acc: 0.9700
# Epoch 11, Loss: 0.1615, Train Acc: 0.9900, Val Acc: 0.9900
# Epoch 12, Loss: 0.1511, Train Acc: 1.0000, Val Acc: 1.0000
# Epoch 13, Loss: 0.1431, Train Acc: 1.0000, Val Acc: 1.0000
# Epoch 14, Loss: 0.1235, Train Acc: 1.0000, Val Acc: 1.0000
# Epoch 15, Loss: 0.1188, Train Acc: 1.0000, Val Acc: 1.0000
# Epoch 16, Loss: 0.1193, Train Acc: 1.0000, Val Acc: 1.0000
# Epoch 17, Loss: 0.1120, Train Acc: 0.9800, Val Acc: 0.9800
# Epoch 18, Loss: 0.1029, Train Acc: 0.9900, Val Acc: 0.9900
# Epoch 19, Loss: 0.0930, Train Acc: 1.0000, Val Acc: 1.0000
# Epoch 20, Loss: 0.0963, Train Acc: 1.0000, Val Acc: 1.0000
# Epoch 21, Loss: 0.0780, Train Acc: 1.0000, Val Acc: 1.0000
# Epoch 22, Loss: 0.0795, Train Acc: 1.0000, Val Acc: 1.0000
# Epoch 23, Loss: 0.0792, Train Acc: 1.0000, Val Acc: 1.0000
# Epoch 24, Loss: 0.0734, Train Acc: 0.9900, Val Acc: 0.9900
# Epoch 25, Loss: 0.0765, Train Acc: 0.9900, Val Acc: 0.9900
# Epoch 26, Loss: 0.0716, Train Acc: 1.0000, Val Acc: 1.0000
# Epoch 27, Loss: 0.0612, Train Acc: 1.0000, Val Acc: 1.0000
# Epoch 28, Loss: 0.0721, Train Acc: 1.0000, Val Acc: 1.0000
# Epoch 29, Loss: 0.0685, Train Acc: 1.0000, Val Acc: 1.0000
# Epoch 30, Loss: 0.0805, Train Acc: 1.0000, Val Acc: 1.0000
# Epoch 31, Loss: 0.0745, Train Acc: 1.0000, Val Acc: 1.0000
# Epoch 32, Loss: 0.0641, Train Acc: 1.0000, Val Acc: 1.0000
# Epoch 33, Loss: 0.0625, Train Acc: 1.0000, Val Acc: 1.0000
# Epoch 34, Loss: 0.0639, Train Acc: 0.9900, Val Acc: 0.9900
# Epoch 35, Loss: 0.0592, Train Acc: 1.0000, Val Acc: 1.0000
# Epoch 36, Loss: 0.0589, Train Acc: 0.9900, Val Acc: 0.9900
# Epoch 37, Loss: 0.0643, Train Acc: 1.0000, Val Acc: 1.0000
# Epoch 38, Loss: 0.0593, Train Acc: 1.0000, Val Acc: 1.0000
# Epoch 39, Loss: 0.0528, Train Acc: 1.0000, Val Acc: 1.0000
# Epoch 40, Loss: 0.0625, Train Acc: 1.0000, Val Acc: 1.0000
# Epoch 41, Loss: 0.0568, Train Acc: 1.0000, Val Acc: 1.0000
# Epoch 42, Loss: 0.0616, Train Acc: 1.0000, Val Acc: 1.0000
# Epoch 43, Loss: 0.0527, Train Acc: 1.0000, Val Acc: 1.0000
# Epoch 44, Loss: 0.0520, Train Acc: 0.9900, Val Acc: 0.9900
# Epoch 45, Loss: 0.0583, Train Acc: 1.0000, Val Acc: 1.0000
# Epoch 46, Loss: 0.0554, Train Acc: 1.0000, Val Acc: 1.0000
# Epoch 47, Loss: 0.0519, Train Acc: 1.0000, Val Acc: 1.0000
# Epoch 48, Loss: 0.0519, Train Acc: 1.0000, Val Acc: 1.0000
# Epoch 49, Loss: 0.0496, Train Acc: 1.0000, Val Acc: 1.0000
# Epoch 50, Loss: 0.0510, Train Acc: 1.0000, Val Acc: 1.0000
# Epoch 51, Loss: 0.0495, Train Acc: 1.0000, Val Acc: 1.0000
# Epoch 52, Loss: 0.0537, Train Acc: 0.9900, Val Acc: 0.9900
# Epoch 53, Loss: 0.0565, Train Acc: 0.9900, Val Acc: 0.9900
# Epoch 54, Loss: 0.0574, Train Acc: 1.0000, Val Acc: 1.0000
# Epoch 55, Loss: 0.0472, Train Acc: 1.0000, Val Acc: 1.0000
# Epoch 56, Loss: 0.0549, Train Acc: 1.0000, Val Acc: 1.0000
# Epoch 57, Loss: 0.0569, Train Acc: 1.0000, Val Acc: 1.0000
# Epoch 58, Loss: 0.0632, Train Acc: 1.0000, Val Acc: 1.0000
# Epoch 59, Loss: 0.0462, Train Acc: 1.0000, Val Acc: 1.0000
# Epoch 60, Loss: 0.0584, Train Acc: 0.9900, Val Acc: 0.9900
# Epoch 61, Loss: 0.0535, Train Acc: 1.0000, Val Acc: 1.0000
# Epoch 62, Loss: 0.0504, Train Acc: 0.9900, Val Acc: 0.9900
# Epoch 63, Loss: 0.0458, Train Acc: 0.9900, Val Acc: 0.9900
# Epoch 64, Loss: 0.0477, Train Acc: 1.0000, Val Acc: 1.0000
# Epoch 65, Loss: 0.0548, Train Acc: 1.0000, Val Acc: 1.0000
# Epoch 66, Loss: 0.0373, Train Acc: 1.0000, Val Acc: 1.0000
# Epoch 67, Loss: 0.0428, Train Acc: 0.9900, Val Acc: 0.9900
# Epoch 68, Loss: 0.0618, Train Acc: 0.9900, Val Acc: 0.9900
# Epoch 69, Loss: 0.0498, Train Acc: 1.0000, Val Acc: 1.0000
# Epoch 70, Loss: 0.0380, Train Acc: 1.0000, Val Acc: 1.0000
# Epoch 71, Loss: 0.0475, Train Acc: 1.0000, Val Acc: 1.0000
# Epoch 72, Loss: 0.0454, Train Acc: 1.0000, Val Acc: 1.0000
# Epoch 73, Loss: 0.0466, Train Acc: 0.9900, Val Acc: 0.9900
# Epoch 74, Loss: 0.0535, Train Acc: 1.0000, Val Acc: 1.0000
# Epoch 75, Loss: 0.0476, Train Acc: 0.9900, Val Acc: 0.9900
# Epoch 76, Loss: 0.0516, Train Acc: 1.0000, Val Acc: 1.0000
# Epoch 77, Loss: 0.0481, Train Acc: 1.0000, Val Acc: 1.0000
# Epoch 78, Loss: 0.0590, Train Acc: 1.0000, Val Acc: 1.0000
# Epoch 79, Loss: 0.0540, Train Acc: 1.0000, Val Acc: 1.0000
# Epoch 80, Loss: 0.0528, Train Acc: 1.0000, Val Acc: 1.0000
# Epoch 81, Loss: 0.0401, Train Acc: 1.0000, Val Acc: 1.0000
# Epoch 82, Loss: 0.0420, Train Acc: 1.0000, Val Acc: 1.0000
# Epoch 83, Loss: 0.0490, Train Acc: 1.0000, Val Acc: 1.0000
# Epoch 84, Loss: 0.0422, Train Acc: 1.0000, Val Acc: 1.0000
# Epoch 85, Loss: 0.0569, Train Acc: 1.0000, Val Acc: 1.0000
# Epoch 86, Loss: 0.0539, Train Acc: 0.9900, Val Acc: 0.9900
# Epoch 87, Loss: 0.0566, Train Acc: 1.0000, Val Acc: 1.0000
# Epoch 88, Loss: 0.0450, Train Acc: 1.0000, Val Acc: 1.0000
# Epoch 89, Loss: 0.0490, Train Acc: 1.0000, Val Acc: 1.0000
# Epoch 90, Loss: 0.0469, Train Acc: 1.0000, Val Acc: 1.0000
# Epoch 91, Loss: 0.0526, Train Acc: 1.0000, Val Acc: 1.0000
# Epoch 92, Loss: 0.0507, Train Acc: 1.0000, Val Acc: 1.0000
# Epoch 93, Loss: 0.0413, Train Acc: 0.9900, Val Acc: 0.9900
# Epoch 94, Loss: 0.0532, Train Acc: 0.9900, Val Acc: 0.9900
# Epoch 95, Loss: 0.0486, Train Acc: 0.9900, Val Acc: 0.9900
# Epoch 96, Loss: 0.0488, Train Acc: 1.0000, Val Acc: 1.0000
# Epoch 97, Loss: 0.0558, Train Acc: 1.0000, Val Acc: 1.0000
# Epoch 98, Loss: 0.0523, Train Acc: 1.0000, Val Acc: 1.0000
# Epoch 99, Loss: 0.0502, Train Acc: 1.0000, Val Acc: 1.0000
# Epoch 100, Loss: 0.0426, Train Acc: 1.0000, Val Acc: 1.0000
# Test Accuracy: 0.9727
#
#  All Results Saved in training_results.xlsx
